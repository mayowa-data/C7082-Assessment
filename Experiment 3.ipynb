# %% [markdown]
# <a href="https://colab.research.google.com/github/mayowa-data/C7082/blob/main/C7082Assessment_increased_epoch_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import Sequential
import keras  
import os
import glob 
import matplotlib.pyplot as plt
import numpy as np
import PIL
from PIL import Image
from skimage import io 
from os import listdir
import random 
import numpy as np
import matplotlib.pyplot as plt  
# %matplotlib inline
import tensorflow_datasets as tfds

# %%
crops_dir = '/content/drive/MyDrive/Agricultural-crops'
crops_dir = os.path.join(crops_dir)
crops_dir= glob.glob(crops_dir)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/Agricultural-crops',
validation_split=0.4,
subset="training",
seed=123,
image_size=(img_height, img_width),
batch_size= batch_size)
# Out:
# Found 770 files belonging to 30 classes.
# Using 462 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/Agricultural-crops',
  validation_split=0.4,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 770 files belonging to 30 classes.
# Using 308 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Cherry', 'Coffee-plant', 'Cucumber', 'Fox_nut(Makhana)', 'Lemon', 'Olive-tree', 'Pearl_millet(bajra)', 'Tobacco-plant', 'almond', 'banana', 'cardamom', 'chilli', 'clove', 'coconut', 'cotton', 'gram', 'jowar', 'jute', 'maize', 'mustard-oil', 'papaya', 'pineapple', 'rice', 'soyabean', 'sugarcane', 'sunflower', 'tea', 'tomato', 'vigna-radiati(Mung)', 'wheat']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.99832433

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=50
history= model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 106s 7s/step - loss: 3.4661 - accuracy: 0.0390 - val_loss: 3.3739 - val_accuracy: 0.0519
# Epoch 2/50
# 15/15 [==============================] - 0s 32ms/step - loss: 3.2053 - accuracy: 0.1364 - val_loss: 3.2646 - val_accuracy: 0.0649
# Epoch 3/50
# 15/15 [==============================] - 0s 29ms/step - loss: 2.8086 - accuracy: 0.2424 - val_loss: 3.1507 - val_accuracy: 0.1494
# Epoch 4/50
# 15/15 [==============================] - 0s 29ms/step - loss: 2.4283 - accuracy: 0.3485 - val_loss: 2.9366 - val_accuracy: 0.2110
# Epoch 5/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.8522 - accuracy: 0.4870 - val_loss: 3.0836 - val_accuracy: 0.2240
# Epoch 6/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.2565 - accuracy: 0.6602 - val_loss: 2.9595 - val_accuracy: 0.3117
# Epoch 7/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8474 - accuracy: 0.7792 - val_loss: 3.1493 - val_accuracy: 0.2922
# Epoch 8/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.4669 - accuracy: 0.8810 - val_loss: 3.5118 - val_accuracy: 0.2403
# Epoch 9/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2985 - accuracy: 0.9199 - val_loss: 3.4610 - val_accuracy: 0.2955
# Epoch 10/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2003 - accuracy: 0.9567 - val_loss: 4.1042 - val_accuracy: 0.2370
# Epoch 11/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0974 - accuracy: 0.9805 - val_loss: 3.9751 - val_accuracy: 0.2792
# Epoch 33/50
# 15/15 [==============================] - 0s 29ms/step - loss: 3.5366e-04 - accuracy: 1.0000 - val_loss: 4.7635 - val_accuracy: 0.3312
# Epoch 34/50
# 15/15 [==============================] - 0s 27ms/step - loss: 3.3425e-04 - accuracy: 1.0000 - val_loss: 4.7837 - val_accuracy: 0.3377
# Epoch 35/50
# 15/15 [==============================] - 0s 27ms/step - loss: 3.1827e-04 - accuracy: 1.0000 - val_loss: 4.8036 - val_accuracy: 0.3377
# Epoch 36/50
# 15/15 [==============================] - 0s 28ms/step - loss: 3.0323e-04 - accuracy: 1.0000 - val_loss: 4.8213 - val_accuracy: 0.3344
# Epoch 37/50
# 15/15 [==============================] - 0s 27ms/step - loss: 2.8876e-04 - accuracy: 1.0000 - val_loss: 4.8341 - val_accuracy: 0.3344
# Epoch 38/50
# 15/15 [==============================] - 0s 27ms/step - loss: 2.7532e-04 - accuracy: 1.0000 - val_loss: 4.8475 - val_accuracy: 0.3344
# Epoch 39/50
# 15/15 [==============================] - 0s 28ms/step - loss: 2.6350e-04 - accuracy: 1.0000 - val_loss: 4.8649 - val_accuracy: 0.3312
# Epoch 40/50
# 15/15 [==============================] - 0s 28ms/step - loss: 2.5285e-04 - accuracy: 1.0000 - val_loss: 4.8777 - val_accuracy: 0.3312
# Epoch 41/50
# 15/15 [==============================] - 0s 28ms/step - loss: 2.4273e-04 - accuracy: 1.0000 - val_loss: 4.8963 - val_accuracy: 0.3344
# Epoch 42/50
# 15/15 [==============================] - 0s 27ms/step - loss: 2.3207e-04 - accuracy: 1.0000 - val_loss: 4.9115 - val_accuracy: 0.3312
# Epoch 43/50
# 15/15 [==============================] - 0s 28ms/step - loss: 2.2308e-04 - accuracy: 1.0000 - val_loss: 4.9216 - val_accuracy: 0.3344
# Epoch 44/50
# 15/15 [==============================] - 0s 28ms/step - loss: 2.1419e-04 - accuracy: 1.0000 - val_loss: 4.9344 - val_accuracy: 0.3344
# Epoch 45/50
# 15/15 [==============================] - 0s 27ms/step - loss: 2.0635e-04 - accuracy: 1.0000 - val_loss: 4.9510 - val_accuracy: 0.3344
# Epoch 46/50
# 15/15 [==============================] - 0s 27ms/step - loss: 1.9909e-04 - accuracy: 1.0000 - val_loss: 4.9640 - val_accuracy: 0.3312
# Epoch 47/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.9145e-04 - accuracy: 1.0000 - val_loss: 4.9752 - val_accuracy: 0.3312
# Epoch 48/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.8505e-04 - accuracy: 1.0000 - val_loss: 4.9891 - val_accuracy: 0.3344
# Epoch 49/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7867e-04 - accuracy: 1.0000 - val_loss: 4.9948 - val_accuracy: 0.3344
# Epoch 50/50
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7245e-04 - accuracy: 1.0000 - val_loss: 5.0070 - val_accuracy: 0.3344

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_2 (Flatten)         (None, 30976)             0
#
#  dense_4 (Dense)             (None, 128)               3965056
#
#  outputs (Dense)             (None, 30)                3870
#
# =================================================================
# Total params: 3,992,510
# Trainable params: 3,992,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 2s 55ms/step - loss: 3.4820 - accuracy: 0.0368 - val_loss: 3.3485 - val_accuracy: 0.0325
# Epoch 2/50
# 15/15 [==============================] - 1s 43ms/step - loss: 3.3241 - accuracy: 0.0455 - val_loss: 3.3198 - val_accuracy: 0.0390
# Epoch 3/50
# 15/15 [==============================] - 1s 43ms/step - loss: 3.1929 - accuracy: 0.0952 - val_loss: 3.2301 - val_accuracy: 0.1039
# Epoch 4/50
# 15/15 [==============================] - 1s 43ms/step - loss: 3.0391 - accuracy: 0.1494 - val_loss: 3.1246 - val_accuracy: 0.0909
# Epoch 5/50
# 15/15 [==============================] - 1s 44ms/step - loss: 2.8667 - accuracy: 0.1797 - val_loss: 3.2232 - val_accuracy: 0.1136
# Epoch 6/50
# 15/15 [==============================] - 1s 43ms/step - loss: 2.7092 - accuracy: 0.2186 - val_loss: 2.9955 - val_accuracy: 0.1721
# Epoch 7/50
# 15/15 [==============================] - 1s 44ms/step - loss: 2.5894 - accuracy: 0.2468 - val_loss: 3.0969 - val_accuracy: 0.1786
# Epoch 8/50
# 15/15 [==============================] - 1s 44ms/step - loss: 2.4376 - accuracy: 0.2922 - val_loss: 2.9585 - val_accuracy: 0.1753
# Epoch 9/50
# 15/15 [==============================] - 1s 42ms/step - loss: 2.3732 - accuracy: 0.3420 - val_loss: 2.9698 - val_accuracy: 0.1818
# Epoch 10/50
# 15/15 [==============================] - 1s 44ms/step - loss: 2.1817 - accuracy: 0.3853 - val_loss: 3.0453 - val_accuracy: 0.1656
# Epoch 11/50
# 15/15 [==============================] - 1s 45ms/step - loss: 1.9922 - accuracy: 0.4416 - val_loss: 3.1274 - val_accuracy: 0.2143
# Epoch 12/50
# 15/15 [==============================] - 1s 42ms/step - loss: 1.8753 - accuracy: 0.4675 - val_loss: 3.0372 - val_accuracy: 0.2045
# Epoch 13/50
# 15/15 [==============================] - 1s 44ms/step - loss: 1.7799 - accuracy: 0.4892 - val_loss: 3.0350 - val_accuracy: 0.2403
# Epoch 14/50
# 15/15 [==============================] - 1s 45ms/step - loss: 1.6116 - accuracy: 0.5173 - val_loss: 3.2320 - val_accuracy: 0.2078
# Epoch 15/50
# 15/15 [==============================] - 1s 42ms/step - loss: 1.5286 - accuracy: 0.5281 - val_loss: 3.3548 - val_accuracy: 0.2208
# Epoch 16/50
# 15/15 [==============================] - 1s 42ms/step - loss: 1.6274 - accuracy: 0.5498 - val_loss: 3.4907 - val_accuracy: 0.1948
# Epoch 17/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.5988 - accuracy: 0.7987 - val_loss: 5.2109 - val_accuracy: 0.2727
# Epoch 38/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.3821 - accuracy: 0.8874 - val_loss: 4.7592 - val_accuracy: 0.3052
# Epoch 39/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2580 - accuracy: 0.9199 - val_loss: 5.2030 - val_accuracy: 0.3019
# Epoch 40/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.3375 - accuracy: 0.9004 - val_loss: 5.5705 - val_accuracy: 0.2890
# Epoch 41/50
# 15/15 [==============================] - 1s 42ms/step - loss: 0.3143 - accuracy: 0.9026 - val_loss: 5.2502 - val_accuracy: 0.3019
# Epoch 42/50
# 15/15 [==============================] - 1s 45ms/step - loss: 0.2327 - accuracy: 0.9286 - val_loss: 5.8856 - val_accuracy: 0.2922
# Epoch 43/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2710 - accuracy: 0.8983 - val_loss: 5.7579 - val_accuracy: 0.2955
# Epoch 44/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2108 - accuracy: 0.9524 - val_loss: 5.7872 - val_accuracy: 0.3474
# Epoch 45/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.2232 - accuracy: 0.9286 - val_loss: 5.7522 - val_accuracy: 0.3084
# Epoch 46/50
# 15/15 [==============================] - 1s 44ms/step - loss: 0.1380 - accuracy: 0.9589 - val_loss: 6.3316 - val_accuracy: 0.3052
# Epoch 47/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.1898 - accuracy: 0.9437 - val_loss: 6.7599 - val_accuracy: 0.2727
# Epoch 48/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.2457 - accuracy: 0.9372 - val_loss: 6.6039 - val_accuracy: 0.3019
# Epoch 49/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.2224 - accuracy: 0.9307 - val_loss: 6.3476 - val_accuracy: 0.2695
# Epoch 50/50
# 15/15 [==============================] - 1s 43ms/step - loss: 0.2031 - accuracy: 0.9459 - val_loss: 5.5777 - val_accuracy: 0.3149

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
almond_dir = '/content/drive/MyDrive/Agricultural-crops/almond/image (23).jpg'
almond_path = os.path.join('/content/drive/MyDrive/Agricultural-crops/almond')
from PIL import Image
img_data = np.random.random(size=(180, 180, 3))
img = tf.keras.preprocessing.image.array_to_img(img_data)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# This image most likely belongs to almond with a 83.74 percent confidence.

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
TF_MODEL_FILE_PATH = 'model.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['sequential_2_input'], 'outputs': ['outputs']}}

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %%
predictions_lite = classify_lite(sequential_2_input=img_array)['outputs']
score_lite = tf.nn.softmax(predictions_lite)

# %%
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score_lite)], 100 * np.max(score_lite))
)
# Out:
# This image most likely belongs to almond with a 83.74 percent confidence.

# %%
print(np.max(np.abs(predictions - predictions_lite)))
# Out:
# 7.6293945e-06
